# %% [markdown]
# ## Plotly - Scatter Chart di Plotly
#
# Berikut ini cara membuat scatter chart di plotly.
#
# Referensi : https://dash.plot.ly/?_ga=2.221052315.2054414018.1576406660-399155170.1567829979

# %%
#memasukan modul yang digunakan
import numpy as np
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
#memasukan data 
data = pd.read_excel('sales.xls')
data.head()
# Out:
#    Row ID  Order ID Order Date  ... Product Container  Product Base Margin  Ship Date
# 0       1         3 2010-10-13  ...         Large Box                 0.80 2010-10-20
# 1      49       293 2012-10-01  ...        Jumbo Drum                 0.58 2012-10-02
# 2      50       293 2012-10-01  ...         Small Box                 0.39 2012-10-03
# 3      80       483 2011-07-10  ...         Small Box                 0.58 2011-07-12
# 4      85       515 2010-08-28  ...        Medium Box                 0.50 2010-08-30
#
# [5 rows x 21 columns]

# %%
#menampilkan data kolom sales dan profit
data1 = data[['Sales', 'Profit']]
data1.head()
# Out:
#         Sales     Profit
# 0    261.5400  -213.2500
# 1  10123.0200   457.8100
# 2    244.5700    46.7075
# 3   4965.7595  1198.9710
# 4    394.2700    30.9400

# %%
#mendefine data di plotly
data = [go.Scatter(
        x = data1.Sales,
        y = data1.Profit,
        mode = 'markers',
        marker = dict(size = 14, 
                      color = 'rgb(120,150,100)', 
                      symbol = 'square',
                      line = dict(width = 2)
)    
)]

# %%
#membuat layout
layout = go.Layout(
        title = 'Sales dan Profit Chart',
        xaxis = dict(title = 'Sales di X'),
        yaxis = dict(title = 'Profit di Y'),
        hovermode = 'closest'
)

# %%
#membuat frame
figure = go.Figure(data = data, layout = layout)

# %%
#menampilkan hasil
pyo.plot(figure)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                     #Semoga Bermanfaat
#                     #@Raspiani_
