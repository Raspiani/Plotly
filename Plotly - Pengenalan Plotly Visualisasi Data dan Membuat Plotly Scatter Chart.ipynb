# %% [markdown]
# ## Plotly - Pengenalan Plotly Visualisasi Data dan Membuat Plotly Scatter Chart
#
# Berikut ini pengenalan plotly visualisasi data dan cara membuat plotly scatter chart.

# %%
#memasukan modul yang digunakan
import plotly.offline as pyo
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %%
#membuka data
data = pd.read_excel('sales.xls')
data.head()
# Out:
#    Row ID  Order ID Order Date  ... Product Container  Product Base Margin  Ship Date
# 0       1         3 2010-10-13  ...         Large Box                 0.80 2010-10-20
# 1      49       293 2012-10-01  ...        Jumbo Drum                 0.58 2012-10-02
# 2      50       293 2012-10-01  ...         Small Box                 0.39 2012-10-03
# 3      80       483 2011-07-10  ...         Small Box                 0.58 2011-07-12
# 4      85       515 2010-08-28  ...        Medium Box                 0.50 2010-08-30
#
# [5 rows x 21 columns]

# %%
#Cara I
#membuat plotly scatter chart 
pyo.plot([
    go.Scatter(
    x = data.index,
    y = data.Sales, 
    mode = 'markers'
    )
])

#hasilnya seperti gambar di bawah ini
# Out:
# 'temp-plot.html'

# %%
#cara II
data = go.Scatter(x = data.index, y = data.Sales, mode = 'markers')

#Membuat plotly scatter plot
pyo.plot([data])
# Out:
# 'temp-plot.html'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                     #Semoga Bermanfaat
#                     #@Raspiani_
