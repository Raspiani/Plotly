# %% [markdown]
# ## Plotly - Pengenalan Plotly Visualisasi Data dan Membuat Plotly Chart
#
# Berikut ini pengenalan plotly visualisasi data dan cara membuat plotly chart.

# %%
#memasukan modul yang digunakan
import plotly.offline as pyo
import pandas as pd
import matplotlib.pyplot as plt

# %%
#membuka data
data = pd.read_excel('sales.xls')
data.head()
# Out:
#    Row ID  Order ID Order Date  ... Product Container  Product Base Margin  Ship Date
# 0       1         3 2010-10-13  ...         Large Box                 0.80 2010-10-20
# 1      49       293 2012-10-01  ...        Jumbo Drum                 0.58 2012-10-02
# 2      50       293 2012-10-01  ...         Small Box                 0.39 2012-10-03
# 3      80       483 2011-07-10  ...         Small Box                 0.58 2011-07-12
# 4      85       515 2010-08-28  ...        Medium Box                 0.50 2010-08-30
#
# [5 rows x 21 columns]

# %%
#melihat info data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
# Row ID                  8399 non-null int64
# Order ID                8399 non-null int64
# Order Date              8399 non-null datetime64[ns]
# Order Priority          8399 non-null object
# Order Quantity          8399 non-null int64
# Sales                   8399 non-null float64
# Discount                8399 non-null float64
# Ship Mode               8399 non-null object
# Profit                  8399 non-null float64
# Unit Price              8399 non-null float64
# Shipping Cost           8399 non-null float64
# Customer Name           8399 non-null object
# Province                8399 non-null object
# Region                  8399 non-null object
# Customer Segment        8399 non-null object
# Product Category        8399 non-null object
# Product Sub-Category    8399 non-null object
# Product Name            8399 non-null object
# ...

# %%
#membuat barchart dengan matplotlib
plt.plot(data.Sales)
plt.show()

# %%
#membuat plotly chart 
#membuat barchart dengan plotly
pyo.plot([{
    'x' : data.index,
    'y' : data.Sales
}])

#hasilnya seperti gambar di bawah ini
# Out:
# 'temp-plot.html'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data1 = data[['Sales', 'Profit']]
data1.head()
# Out:
#         Sales     Profit
# 0    261.5400  -213.2500
# 1  10123.0200   457.8100
# 2    244.5700    46.7075
# 3   4965.7595  1198.9710
# 4    394.2700    30.9400

# %%
pyo.plot([{
    'x' : data1.index,
    'y' : data1[col],
    'name' : col} for col in data1.columns ])
# Out:
# 'temp-plot.html'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                     #Semoga Bermanfaat
#                     #@Raspiani_
